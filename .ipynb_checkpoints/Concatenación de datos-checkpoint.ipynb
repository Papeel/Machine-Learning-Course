# %% [markdown]
# # Concatenar y apendizar datasets

# %%
import pandas as pd

# %%
red_wine =  pd.read_csv("./datasets/wine/winequality-red.csv", sep=";")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
red_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine =  pd.read_csv("./datasets/wine/winequality-white.csv", sep=";")
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white_wine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# En python, tenemos dos tipos de ejes,
# * axis = 0 denota el eje horizontal
# * axis = 1 denota el eje vertical

# %%
wine_data = pd.concat([red_wine, white_wine], ignore_index=True, axis = 0)

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine_data.shape
# Out:
# (6497, 12)

# %%
data1 = wine_data.head(10)
data2 =  wine_data[300:310]
data3 =  wine_data.tail(10)

# %%
wine_scramble = pd.concat([data2, data3, data1], axis=0)

# %%
wine_scramble
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 300             7.5             0.530         0.06            2.60      0.086
# 301            11.1             0.180         0.48            1.50      0.068
# 302             8.3             0.705         0.12            2.60      0.092
# 303             7.4             0.670         0.12            1.60      0.186
# 304             8.4             0.650         0.60            2.10      0.112
# 305            10.3             0.530         0.48            2.50      0.063
# 306             7.6             0.620         0.32            2.20      0.082
# 307            10.3             0.410         0.42            2.40      0.213
# 308            10.3             0.430         0.44            2.40      0.214
# 309             7.4             0.290         0.38            1.70      0.062
# 6487            6.8             0.220         0.36            1.20      0.052
# 6488            4.9             0.235         0.27           11.75      0.030
# 6489            6.1             0.340         0.29            2.20      0.036
# 6490            5.7             0.210         0.32            0.90      0.038
# 6491            6.5             0.230         0.38            1.30      0.032
# 6492            6.2             0.210         0.29            1.60      0.039
# 6493            6.6             0.320         0.36            8.00      0.047
# 6494            6.5             0.240         0.19            1.20      0.041
# 6495            5.5             0.290         0.30            1.10      0.022
# 6496            6.0             0.210         0.38            0.80      0.020
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 300                  20.0                  44.0  0.99650  3.38       0.59
# 301                   7.0                  15.0  0.99730  3.22       0.64
# 302                  12.0                  28.0  0.99940  3.51       0.72
# 303                   5.0                  21.0  0.99600  3.39       0.54
# 304                  12.0                  90.0  0.99730  3.20       0.52
# 305                   6.0                  25.0  0.99980  3.12       0.59
# 306                   7.0                  54.0  0.99660  3.36       0.52
# 307                   6.0                  14.0  0.99940  3.19       0.62
# 308                   5.0                  12.0  0.99940  3.19       0.63
# 309                   9.0                  30.0  0.99680  3.41       0.53
# 6487                 38.0                 127.0  0.99330  3.04       0.54
# 6488                 34.0                 118.0  0.99540  3.07       0.50
# 6489                 25.0                 100.0  0.98938  3.06       0.44
# 6490                 38.0                 121.0  0.99074  3.24       0.46
# 6491                 29.0                 112.0  0.99298  3.29       0.54
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 6                    15.0                  59.0  0.99640  3.30       0.46
# 7                    15.0                  21.0  0.99460  3.39       0.47
# 8                     9.0                  18.0  0.99680  3.36       0.57
# 9                    17.0                 102.0  0.99780  3.35       0.80
#
#       alcohol  quality
# 300      10.7        6
# 301      10.1        6
# 302      10.0        5
# 303       9.5        5
# 304       9.2        5
# 305       9.3        6
# 306       9.4        5
# 307       9.5        6
# 308       9.5        6
# 309       9.5        6
# 6487      9.2        5
# 6488      9.4        6
# 6489     11.8        6
# 6490     10.6        6
# 6491      9.7        5
# 6492     11.2        6
# 6493      9.6        5
# 6494      9.4        6
# 6495     12.8        7
# 6496     11.8        6
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# 5         9.4        5
# 6         9.4        5
# 7        10.0        7
# 8         9.5        7
# 9        10.5        5

# %% [markdown]
# ## Datos distribuidos

# %%
data = pd.read_csv("./datasets/distributed-data/001.csv")

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %% [markdown]
# * Importar el primer fichero
# * Hacemos un bucle para ir recorriendo cada uno de los ficheros.
#     * Importante tener una consistencia en el nombre de los ficheros
#     * Importamos los ficheros uno a uno
#     * Cada uno de ellos debe apendizarse (añadir al final) del primer fichero que ya teniamos cargado
# * Repetimos el bucle hasta que no queden ficheros

# %%
filepath = "./datasets/distributed-data/"
data = pd.read_csv("./datasets/distributed-data/001.csv")
final_length = len(data)
for i in range(2, 333):
    filename = str(i).zfill(3)
    file = filepath + filename + ".csv"
    
    temp_data = pd.read_csv(file)
    final_length += len(temp_data)
    
    data = pd.concat([data, temp_data], ignore_index=True, axis=0)

# %%
data.shape
# Out:
# (772087, 4)

# %%
data.tail()
# Out:
#               Date  sulfate  nitrate   ID
# 772082  2004-12-27      NaN      NaN  332
# 772083  2004-12-28      NaN      NaN  332
# 772084  2004-12-29      NaN      NaN  332
# 772085  2004-12-30      NaN      NaN  332
# 772086  2004-12-31      NaN      NaN  332

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
final_length == data.shape[0]
# Out:
# True

# %% [markdown]
# ## Joins de datasets

# %%
filepath = "./datasets/athletes/"

# %%
data_main = pd.read_csv(filepath + "Medals.csv", encoding="ISO-8859-1")

# %%
data_main.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# 3              2              3             6
# 4              1              3             6

# %%
a = data_main['Athlete'].unique().tolist()
len(a)
# Out:
# 6956

# %%
data_main.shape
# Out:
# (8618, 8)

# %%
data_country = pd.read_csv(filepath + "Athelete_Country_Map.csv", encoding="ISO-8859-1")

# %%
data_country.head()
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States

# %%
data_country.shape
# Out:
# (6970, 2)

# %%
data_country[data_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
data_sport = pd.read_csv(filepath + "Athelete_Sports_Map.csv", encoding="ISO-8859-1")

# %%
data_sport.head()
# Out:
#             Athlete       Sport
# 0    Michael Phelps    Swimming
# 1  Natalie Coughlin    Swimming
# 2     Aleksey Nemov  Gymnastics
# 3     Alicia Coutts    Swimming
# 4    Missy Franklin    Swimming

# %%
len(data_sport)
# Out:
# 6975

# %%
data_sport[
    (data_sport["Athlete"] == "Chen Jing") |
    (data_sport["Athlete"] == "Richard Thompson") |
    (data_sport["Athlete"] == "Matt Ryan") 
]
# Out:
#                Athlete         Sport
# 528   Richard Thompson     Athletics
# 1308         Chen Jing    Volleyball
# 1419         Chen Jing  Table Tennis
# 2727         Matt Ryan        Rowing
# 5003         Matt Ryan    Equestrian
# 5691  Richard Thompson      Baseball

# %%
data_country_dp = data_country.drop_duplicates(subset="Athlete")

# %%
data_country_dp.shape
# Out:
# (6956, 2)

# %%
data_main_country = pd.merge(left= data_main, right =  data_country_dp,
                            left_on="Athlete", right_on="Athlete")

# %%
data_main_country.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8  United States
# 1              0              2             8  United States
# 2              2              0             6  United States
# 3              2              3             6  United States
# 4              2              1             5  United States

# %%
data_main_country.shape
# Out:
# (8618, 9)

# %%
data_main_country[data_main_country["Athlete"] == "Aleksandar Ciric"]
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1491  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1492  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1493  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals Country
# 1491              0              1             1  Serbia
# 1492              1              0             1  Serbia
# 1493              0              1             1  Serbia

# %%
data_sports_dp = data_sport.drop_duplicates(subset="Athlete")

# %%
data_sports_dp.shape
# Out:
# (6956, 2)

# %%
data_final = pd.merge(left=data_main_country, right= data_sports_dp,
                      left_on="Athlete", right_on="Athlete")

# %%
data_final.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country     Sport
# 0              0              0             8  United States  Swimming
# 1              0              2             8  United States  Swimming
# 2              2              0             6  United States  Swimming
# 3              2              3             6  United States  Swimming
# 4              2              1             5  United States  Swimming

# %%
data_final.shape
# Out:
# (8618, 10)

# %% [markdown]
# ## Tipos de Joins

# %%
from IPython.display import Image
import numpy as np

# %% [markdown]
# ### Inner Join
#
# * Devuelve un data frame con las filas que tienen valor tanto en el primer como en el segundo data frame que estamos uniendo
# * El número de filas será igual al número de filas comunes que tengas ambos data frame
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
# * En terminos de teoría de conjuntos, se trata de la intersección de los dos conjuntos
#
# <img src="resources/inner-join.png">

# %%
Image(filename="resources/inner-join.png")

# %%
out_athletes = np.random.choice(data_main["Athlete"], size=6, replace=False)

# %%
out_athletes
# Out:
# array(['Marcus Becker', 'Katrine Lunde Haraldsen', 'Stephen Holt',
#        'Andrea Sartoretti', 'Aneta Pastuszka-Konieczna',
#        'Hiroyuki Tomita'], dtype=object)

# %%
data_country_dlt = data_country_dp[(~data_country_dp["Athlete"].isin(out_athletes)) & 
                                   (data_country["Athlete"] != "Michael Phelps")
                                  ]

data_sports_dlt = data_sports_dp[(~data_sports_dp["Athlete"].isin(out_athletes)) & 
                                   (data_sports_dp["Athlete"] != "Michael Phelps")
                                  ]

data_main_dlt = data_main[(~data_main["Athlete"].isin(out_athletes)) & 
                                   (data_main["Athlete"] != "Michael Phelps")
                                  ]
# Out:
# D:\Programas_win\anac\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
len(data_country_dlt)
# Out:
# 6949

# %%
len(data_sports_dlt)
# Out:
# 6949

# %%
len(data_main_dlt)
# Out:
# 8604

# %%
merged_inner = pd.merge(left = data_main, right =  data_country_dlt,
                      how =  'inner',  left_on="Athlete", right_on="Athlete")

# %%
len(merged_inner)
# Out:
# 8604

# %%
merged_inner.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008            08/24/2008            1
# 1  Natalie Coughlin  21.0  2004            08/29/2004            2
# 2  Natalie Coughlin  29.0  2012            08/12/2012            0
# 3     Aleksey Nemov  24.0  2000            10/01/2000            2
# 4     Alicia Coutts  24.0  2012            08/12/2012            1
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              2              3             6  United States
# 1              2              1             5  United States
# 2              0              1             1  United States
# 3              1              3             6         Russia
# 4              3              1             5      Australia

# %% [markdown]
# ### Left Join
#
# * Devuelve un data frame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del data frame final que no corresponda a ninguna fila del data frame derecho, tendrán NAs en las columnas del data frame derecho.
# * El número de filas será igual al número de filas del data frame izquierdo
#     * Data Set A tiene 60 filas.
#     * Data Set B tiene 50 filas.
#     * Entonces A Left Join tendrá 60 filas
#
# <img src="resources/left-join.png">

# %%
merged_left = pd.merge(left = data_main, right =  data_country_dlt,
                      how =  'left',  left_on="Athlete", right_on="Athlete")

# %%
len(merged_left)
# Out:
# 8618

# %%
merged_left.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ## Right Join
#
# <img src="resources/right-join.png">

# %%
merged_right = pd.merge(left = data_main_dlt, right =  data_country_dp,
                      how =  'right',  left_on="Athlete", right_on="Athlete")

# %%
len(merged_right)
# Out:
# 8611

# %%
merged_right.head()
# Out:
#             Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0  Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 1  Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
# 2  Natalie Coughlin  29.0  2012.0            08/12/2012          0.0
# 3     Aleksey Nemov  24.0  2000.0            10/01/2000          2.0
# 4     Alicia Coutts  24.0  2012.0            08/12/2012          1.0
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0            2.0            3.0           6.0  United States
# 1            2.0            1.0           5.0  United States
# 2            0.0            1.0           1.0  United States
# 3            1.0            3.0           6.0         Russia
# 4            3.0            1.0           5.0      Australia

# %%
merged_right.tail(10)
# Out:
#                         Athlete   Age    Year Closing Ceremony Date  \
# 8601           Wietse van Alten  21.0  2000.0            10/01/2000
# 8602       Sandra Wagner-Sachse  31.0  2000.0            10/01/2000
# 8603                  Rod White  23.0  2000.0            10/01/2000
# 8604             Michael Phelps   NaN     NaN                   NaN
# 8605            Hiroyuki Tomita   NaN     NaN                   NaN
# 8606          Andrea Sartoretti   NaN     NaN                   NaN
# 8607               Stephen Holt   NaN     NaN                   NaN
# 8608    Katrine Lunde Haraldsen   NaN     NaN                   NaN
# 8609  Aneta Pastuszka-Konieczna   NaN     NaN                   NaN
# 8610              Marcus Becker   NaN     NaN                   NaN
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals        Country
# 8601          0.0            0.0            1.0           1.0    Netherlands
# 8602          0.0            0.0            1.0           1.0        Germany
# 8603          0.0            0.0            1.0           1.0  United States
# 8604          NaN            NaN            NaN           NaN  United States
# 8605          NaN            NaN            NaN           NaN          Japan
# 8606          NaN            NaN            NaN           NaN          Italy
# 8607          NaN            NaN            NaN           NaN      Australia
# 8608          NaN            NaN            NaN           NaN         Norway
# 8609          NaN            NaN            NaN           NaN         Poland
# 8610          NaN            NaN            NaN           NaN        Germany

# %% [markdown]
# ## Outer Join
#
# <img src="resources/outer-join.png">

# %%
data_country_jb = data_country_dlt.append({
    "Athlete" : "Nelson",
    "Country" : "España"
}, ignore_index=True)

# %%
merged_outer = pd.merge(left = data_main, right =  data_country_jb,
                      how =  'outer',  left_on="Athlete", right_on="Athlete")

# %%
len(merged_outer)
# Out:
# 8619

# %%
merged_outer.tail()
# Out:
#                    Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8614      Kateryna Serdiuk  17.0  2000.0            10/01/2000          0.0
# 8615      Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8616  Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8617             Rod White  23.0  2000.0            10/01/2000          0.0
# 8618                Nelson   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# 8614            1.0            0.0           1.0        Ukraine
# 8615            0.0            1.0           1.0    Netherlands
# 8616            0.0            1.0           1.0        Germany
# 8617            0.0            1.0           1.0  United States
# 8618            NaN            NaN           NaN         España
